# %%
from google.colab import drive
import pandas as pd
from glob import glob
import matplotlib.pyplot as plt

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
MAIN_DIR = "/content/drive/MyDrive/PIAIC/assignment_resources/pandas"

# %%
inventory = pd.read_csv(f"{MAIN_DIR}/inventory.csv")
all_census = [pd.read_csv(el) for el in sorted(glob(f"{MAIN_DIR}/states[0-9].csv"))]

# %%
census = pd.concat(all_census)

# %%
census.head(10)
# Out:
#    Unnamed: 0                 State  ...               Income            GenderPop
# 0           0               Alabama  ...   $43296.35860306644    2341093M_2489527F
# 1           1                Alaska  ...   $70354.74390243902      384160M_349215F
# 2           2               Arizona  ...   $54207.82095490716    3299088M_3342840F
# 3           3              Arkansas  ...   $41935.63396778917    1451913M_1506295F
# 4           4            California  ...   $67264.78230266465  19087135M_19334329F
# 5           5              Colorado  ...  $64657.801787164906    2648667M_2630239F
# 0           0              Colorado  ...  $64657.801787164906    2648667M_2630239F
# 1           1           Connecticut  ...    $76146.5605875153    1751607M_1841615F
# 2           2              Delaware  ...   $61827.97663551402      448413M_478041F
# 3           3  District of Columbia  ...   $75466.36363636363      306674M_340810F
#
# [10 rows x 11 columns]

# %%
census.drop("Unnamed: 0", axis=1, inplace=True)

# %%
census.reset_index(drop=True, inplace=True)

# %%
census.head(15)
# Out:
#                    State  TotalPop  ...               Income            GenderPop
# 0                Alabama   4830620  ...   $43296.35860306644    2341093M_2489527F
# 1                 Alaska    733375  ...   $70354.74390243902      384160M_349215F
# 2                Arizona   6641928  ...   $54207.82095490716    3299088M_3342840F
# 3               Arkansas   2958208  ...   $41935.63396778917    1451913M_1506295F
# 4             California  38421464  ...   $67264.78230266465  19087135M_19334329F
# 5               Colorado   5278906  ...  $64657.801787164906    2648667M_2630239F
# 6               Colorado   5278906  ...  $64657.801787164906    2648667M_2630239F
# 7            Connecticut   3593222  ...    $76146.5605875153    1751607M_1841615F
# 8               Delaware    926454  ...   $61827.97663551402      448413M_478041F
# 9   District of Columbia    647484  ...   $75466.36363636363      306674M_340810F
# ...

# %%
census.Income = census.Income.str.replace("$", "").astype(float)

# %%
census.head()
# Out:
#         State  TotalPop  ...        Income            GenderPop
# 0     Alabama   4830620  ...  43296.358603    2341093M_2489527F
# 1      Alaska    733375  ...  70354.743902      384160M_349215F
# 2     Arizona   6641928  ...  54207.820955    3299088M_3342840F
# 3    Arkansas   2958208  ...  41935.633968    1451913M_1506295F
# 4  California  38421464  ...  67264.782303  19087135M_19334329F
#
# [5 rows x 10 columns]

# %%
census.dtypes
# Out:
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income       float64
# GenderPop     object
# dtype: object

# %%
pop = census.GenderPop.replace(["M", "F"], "", regex=True).str.split("_")

# %%
pop.head()
# Out:
# 0      [2341093, 2489527]
# 1        [384160, 349215]
# 2      [3299088, 3342840]
# 3      [1451913, 1506295]
# 4    [19087135, 19334329]
# Name: GenderPop, dtype: object

# %%
men, women = pop.apply(lambda x: x[0]), pop.apply(lambda x: x[1])

# %%
census["Men"], census["Women"] = [men, women]

# %%
women
# Out:
# 0      2489527
# 1       349215
# 2      3342840
# 3      1506295
# 4     19334329
# 5      2630239
# 6      2630239
# 7      1841615
# 8       478041
# 9       340810
# 10    10045763
# 11     5123362
# 12     5123362
# 13      696428
# 14      806083
# 15     6556862
# 16     3333382
# 17     1558931
# 18     1558931
# 19     1453125
# 20     2233145
# 21     2364097
# 22      679019
# 23
# 24
# 25     3455936
# 26     5038598
# 27     2727005
# 28     1536358
# 29     3081445
# 30     3081445
# 31
# 32      939759
# 33     1390901
# 34      670717
# 35     4561386
# 36     4561386
# 37     1051703
# 38    10131373
# 39     5049925
# 40      353677
# 41     5913084
# 42     5913084
# 43     1942789
# 44     1990780
# 45     6534215
# 46     1869213
# 47      543273
# 48      543273
# 49     2455167
# 50      419713
# 51     3331859
# 52    13367298
# 53     1444150
# 54     1444150
# 55      318031
# 56     4195682
# 57     3497739
# 58      937789
# 59     2890732
# ...

# %%
census.head()
# Out:
#         State  TotalPop  ...       Men     Women
# 0     Alabama   4830620  ...   2341093   2489527
# 1      Alaska    733375  ...    384160    349215
# 2     Arizona   6641928  ...   3299088   3342840
# 3    Arkansas   2958208  ...   1451913   1506295
# 4  California  38421464  ...  19087135  19334329
#
# [5 rows x 12 columns]

# %%
census.Men, census.Women = pd.to_numeric(census.Men), pd.to_numeric(census.Women)

# %%
census[["Men", "Women"]]
# Out:
#          Men       Women
# 0    2341093   2489527.0
# 1     384160    349215.0
# 2    3299088   3342840.0
# 3    1451913   1506295.0
# 4   19087135  19334329.0
# 5    2648667   2630239.0
# 6    2648667   2630239.0
# 7    1751607   1841615.0
# 8     448413    478041.0
# 9     306674    340810.0
# 10   9600009  10045763.0
# 11   4883331   5123362.0
# 12   4883331   5123362.0
# 13    709871    696428.0
# 14    810464    806083.0
# 15   6316899   6556862.0
# 16   3235263   3333382.0
# 17   1534595   1558931.0
# 18   1534595   1558931.0
# 19   1439862   1453125.0
# 20   2164208   2233145.0
# 21   2261156   2364097.0
# 22    650081    679019.0
# 23   2872643         NaN
# 24   2872643         NaN
# 25   3249650   3455936.0
# 26   4861973   5038598.0
# 27   2692166   2727005.0
# 28   1451723   1536358.0
# 29   2964003   3081445.0
# 30   2964003   3081445.0
# 31    510163         NaN
# 32    929606    939759.0
# 33   1407735   1390901.0
# 34    653484    670717.0
# 35   4343027   4561386.0
# ...

# %%
census.Women.fillna(census.TotalPop - census.Men, inplace=True)

# %%
census[["Men", "Women"]]
# Out:
#          Men       Women
# 0    2341093   2489527.0
# 1     384160    349215.0
# 2    3299088   3342840.0
# 3    1451913   1506295.0
# 4   19087135  19334329.0
# 5    2648667   2630239.0
# 6    2648667   2630239.0
# 7    1751607   1841615.0
# 8     448413    478041.0
# 9     306674    340810.0
# 10   9600009  10045763.0
# 11   4883331   5123362.0
# 12   4883331   5123362.0
# 13    709871    696428.0
# 14    810464    806083.0
# 15   6316899   6556862.0
# 16   3235263   3333382.0
# 17   1534595   1558931.0
# 18   1534595   1558931.0
# 19   1439862   1453125.0
# 20   2164208   2233145.0
# 21   2261156   2364097.0
# 22    650081    679019.0
# 23   2872643   3057895.0
# 24   2872643   3057895.0
# 25   3249650   3455936.0
# 26   4861973   5038598.0
# 27   2692166   2727005.0
# 28   1451723   1536358.0
# 29   2964003   3081445.0
# 30   2964003   3081445.0
# 31    510163    504536.0
# 32    929606    939759.0
# 33   1407735   1390901.0
# 34    653484    670717.0
# 35   4343027   4561386.0
# ...

# %%
plt.scatter(census.Women, census.Income)
plt.xlabel("Women")
plt.ylabel("Income")
plt.show()

# %%
census.duplicated().value_counts()
# Out:
# False    51
# True      9
# dtype: int64

# %%
census.drop_duplicates(inplace=True)
census.reset_index(drop=True, inplace=True)

# %%
census.duplicated().value_counts()
# Out:
# False    51
# dtype: int64

# %%
plt.clf()
plt.scatter(census.Women, census.Income)
plt.xlabel("Women")
plt.ylabel("Income")
plt.show()

# %%
census.head()
# Out:
#         State  TotalPop  ...       Men       Women
# 0     Alabama   4830620  ...   2341093   2489527.0
# 1      Alaska    733375  ...    384160    349215.0
# 2     Arizona   6641928  ...   3299088   3342840.0
# 3    Arkansas   2958208  ...   1451913   1506295.0
# 4  California  38421464  ...  19087135  19334329.0
#
# [5 rows x 12 columns]

# %%
census.iloc[:, 2:8] = census.iloc[:, 2:8].replace("%", "", regex=True).astype(float)

# %%
census.head()
# Out:
#         State  TotalPop   Hispanic  ...            GenderPop       Men       Women
# 0     Alabama   4830620   3.751616  ...    2341093M_2489527F   2341093   2489527.0
# 1      Alaska    733375   5.909581  ...      384160M_349215F    384160    349215.0
# 2     Arizona   6641928  29.565921  ...    3299088M_3342840F   3299088   3342840.0
# 3    Arkansas   2958208   6.215474  ...    1451913M_1506295F   1451913   1506295.0
# 4  California  38421464  37.291875  ...  19087135M_19334329F  19087135  19334329.0
#
# [5 rows x 12 columns]

# %%
census.isnull().sum()
# Out:
# State        0
# TotalPop     0
# Hispanic     0
# White        0
# Black        0
# Native       0
# Asian        0
# Pacific      4
# Income       0
# GenderPop    0
# Men          0
# Women        0
# dtype: int64

# %%
census.Pacific.fillna(census.Pacific.mean(), inplace=True)

# %%
census.isnull().sum()
# Out:
# State        0
# TotalPop     0
# Hispanic     0
# White        0
# Black        0
# Native       0
# Asian        0
# Pacific      0
# Income       0
# GenderPop    0
# Men          0
# Women        0
# dtype: int64

# %%
def create_histogram(race, color):
  plt.clf()
  plt.hist(census[race],ec="black", color=color)
  plt.title(f"{race} Race")
  plt.xlabel("%age of Population")
  plt.ylabel("Frequence")
  plt.show

# %%
create_histogram("Hispanic", "red")

# %%
create_histogram("White", "yellow")

# %%
create_histogram("Hispanic", "magenta")

# %%
create_histogram("Black", "grey")

# %%
create_histogram("Native", "tan")

# %%
create_histogram("Asian", "blue")

# %%
create_histogram("Pacific", "green")

# %%
inventory = pd.read_csv(f"{MAIN_DIR}/inventory.csv")

# %%
inventory.head(10)
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
staten_island = inventory.iloc[:10,]

# %%
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
product_request = staten_island.product_description

# %%
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
seed_request = inventory[(inventory["location"] == "Brooklyn") & (inventory["product_type"] == "seeds")]

# %%
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
inventory["in_stock"] = inventory.quantity != 0

# %%
inventory
# Out:
#          location  product_type  ...  price  in_stock
# 0   Staten Island         seeds  ...   6.99      True
# 1   Staten Island         seeds  ...  19.99      True
# 2   Staten Island         seeds  ...  13.99      True
# 3   Staten Island  garden tools  ...  13.99      True
# 4   Staten Island  garden tools  ...  89.99     False
# 5   Staten Island  garden tools  ...  19.99      True
# 6   Staten Island  pest_control  ...  12.99      True
# 7   Staten Island  pest_control  ...  23.99      True
# 8   Staten Island       planter  ...  17.99     False
# 9   Staten Island       planter  ...   3.99      True
# 10       Brooklyn         seeds  ...   6.99      True
# 11       Brooklyn         seeds  ...  19.99     False
# 12       Brooklyn         seeds  ...  13.99     False
# 13       Brooklyn  garden tools  ...  13.99      True
# 14       Brooklyn  garden tools  ...  89.99      True
# 15       Brooklyn  garden tools  ...  19.99      True
# ...

# %%
inventory["total_value"] = inventory["price"] * inventory["quantity"]
inventory
# Out:
#          location  product_type  ... in_stock  total_value
# 0   Staten Island         seeds  ...     True        27.96
# 1   Staten Island         seeds  ...     True       919.54
# 2   Staten Island         seeds  ...     True      1189.15
# 3   Staten Island  garden tools  ...     True        55.96
# 4   Staten Island  garden tools  ...    False         0.00
# 5   Staten Island  garden tools  ...     True      1859.07
# 6   Staten Island  pest_control  ...     True       961.26
# 7   Staten Island  pest_control  ...     True       191.92
# 8   Staten Island       planter  ...    False         0.00
# 9   Staten Island       planter  ...     True       211.47
# 10       Brooklyn         seeds  ...     True       349.50
# 11       Brooklyn         seeds  ...    False         0.00
# 12       Brooklyn         seeds  ...    False         0.00
# 13       Brooklyn  garden tools  ...     True       209.85
# 14       Brooklyn  garden tools  ...     True      7379.18
# ...

# %%
combine_lambda = lambda row:'{} - {}'.format(row.product_type, row.product_description)

# %%
inventory['full_description'] = inventory.apply(combine_lambda, axis=1)

# %%
inventory
# Out:
#          location  ...                      full_description
# 0   Staten Island  ...                         seeds - daisy
# 1   Staten Island  ...                    seeds - calla lily
# 2   Staten Island  ...                        seeds - tomato
# 3   Staten Island  ...                   garden tools - rake
# 4   Staten Island  ...            garden tools - wheelbarrow
# 5   Staten Island  ...                  garden tools - spade
# 6   Staten Island  ...          pest_control - insect killer
# 7   Staten Island  ...            pest_control - weed killer
# 8   Staten Island  ...  planter - 20 inch terracotta planter
# 9   Staten Island  ...      planter - 8 inch plastic planter
# 10       Brooklyn  ...                         seeds - daisy
# 11       Brooklyn  ...                    seeds - calla lily
# 12       Brooklyn  ...                        seeds - tomato
# 13       Brooklyn  ...                   garden tools - rake
# ...
